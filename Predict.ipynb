# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd drive/MyDrive/DATASET CHOICE A
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/DATASET CHOICE A'
# /content/drive/.shortcut-targets-by-id/1sQ6yVOJcEUxxfbO86PTt5SqhzTJOfLGN/DATASET CHOICE A

# %%
# coding: utf-8
import matplotlib.pyplot as plt
from mnist import load_mnist
from multi_layer_net import *
import numpy as np
from PIL import Image
from tensorflow.keras.preprocessing.image import img_to_array
from keras.preprocessing import image as keras_image

# %%
input_shape = (28, 28, 1)  # Input shape for MNIST images
num_classes = 10  # Number of output classes for MNIST digits
model = MultiLayerNetKeras(input_shape=input_shape, num_classes=num_classes)
model.load_model("saved_model.h5")
# Out:
# Model loaded successfully.

# %%
image_path = "test.png"
img = Image.open(image_path).convert("L")

# %%
plt.figure(figsize=(5, 5))
plt.imshow(img, cmap='gray')
plt.title('Goc')
plt.show()

# %%
# Resize the image to match the input shape of the model
img = img.resize((28, 28))
img_array = img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

# Display the resized image
plt.figure(figsize=(5, 5))
plt.imshow(np.squeeze(img_array), cmap='gray')
plt.title('Xu ly')
plt.show()

# %%
# Make a prediction
predicted_probs = model.predict(img_array)
predicted_class = np.argmax(predicted_probs)

# Assuming you have a list of class labels for reference
class_labels = ['T-shirt/top', 'Trouser/pants', 'Pullover shirt', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']  # Replace with your actual class labels
predicted_label = class_labels[predicted_class]

print("Du doan nhan:", predicted_class , predicted_label)
# print("Predicted probabilities:", predicted_probs)
# Out:
# 1/1 [==============================] - 0s 100ms/step
# Du doan nhan: 0 T-shirt/top
